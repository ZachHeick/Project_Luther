# %%
from bs4 import BeautifulSoup
import requests
from pprint import pprint
import pandas as pd
import numpy as np
from pprint import pprint
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from collections import OrderedDict
import time
import os
import pickle
import random

# %%
chromedriver = '/Applications/chromedriver'
os.environ['webdriver.chrome.driver'] = chromedriver
driver = webdriver.Chrome(chromedriver)

# %%
url = 'http://www.rogerebert.com/reviews'
driver.get(url)

# %%
reviewer_form = driver.find_element_by_class_name('search-field').click()
reviewer_list = driver.find_element_by_class_name('chosen-results')
for review in driver.find_elements_by_tag_name('li'):
    if review.text == 'Roger Ebert':
        review.click()
        break

# %%
check_box = driver.find_element_by_id('no_stars').click()

# %%
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(3)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
def get_movie_details(movie_url):
    sleep_interval = random.randint(0,1)
    time.sleep(sleep_interval)
    url = 'http://www.rogerebert.com' + movie_url
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,'html5lib')
    
    details_d = OrderedDict()
    details_d['genre'] = ''
    details_d['sub-genre'] = ''
    details_d['mpaa-rating'] = ''
    details_d['running-time'] = ''
    
    movie_details = []
    for detail in soup.find(class_='more-details').findChildren('p'):

        detail_class = detail['class'][0]
        detail_text = [item for item in detail.text.split('\n') if item != '']
        
        if detail_class == 'genres':
            genres = detail_text[0].split(', ')
            details_d['genre'] = genres[0]
            if len(genres) > 1:
                details_d['sub-genre'] = genres[1]
        if detail_class == 'mpaa-rating':
            details_d[detail_class] = detail_text[0].split(' ')[1]
        if detail_class == 'running-time':
            details_d[detail_class] = int(detail_text[0].split(' ')[0])
    
    genre = details_d['genre']
    sub_genre = details_d['sub-genre']
    mpaa_rating = details_d['mpaa-rating']
    running_time = details_d['running-time']
    
    return genre, sub_genre, mpaa_rating, running_time

# %%
def calculate_numeric_rating(star_ratings):
    rating_conversion = {
        'icon-star-full': 1,
        'icon-star-half': 0.5,
        'icon-thumbsdown': 0
    }
    
    numeric_rating = []
    for star in star_ratings:
        numeric_rating.append(rating_conversion[star])
    
    return sum(numeric_rating)

# %%
reviews = []
for review in soup.find_all(class_='movie review'):
    movie_info = [item for item in review.text.split('\n') if item != '']
    
    if len(movie_info) == 2:
        movie_info.append('')
        
    movie_title = movie_info[0]
    movie_year = movie_info[2]
    
    if movie_year != '':
        movie_year = int(movie_year.replace('(', '').replace(')', ''))
    
    rating = review.find(class_='star-rating').findChildren()
    star_ratings = [rate['class'][0] for rate in rating]  
    numeric_rating = calculate_numeric_rating(star_ratings)
    
    review_link = review.find('a', class_='poster')['href']  
    genre, sub_genre, mpaa_rating, running_time = get_movie_details(review_link)

    movie = (movie_title, movie_year, numeric_rating, genre, sub_genre, mpaa_rating, running_time)
    
    reviews.append(movie)

# %%
df = pd.DataFrame(reviews, columns=['Title', 'Year', 'Star_Score', 'Genre', 'Sub-genre', 'Rating', 'Runtime'])
df
# Out:
#                                                   Title  Year  Star_Score  \
# 0                                   The Spectacular Now  2013         4.0
# 1                                        Computer Chess  2013         2.0
# 2                                          At Any Price  2012         4.0
# 3                                          Blancanieves  2012         4.0
# 4     Deceptive Practice: The Mysteries and Mentors ...  2013         3.0
# 5                                         To the Wonder  2013         3.5
# 6                                 From Up on Poppy Hill  2013         2.5
# 7                                              The Host  2013         2.5
# 8                                       Ginger and Rosa  2013         3.0
# 9                                           On the Road  2013         2.0
# 10                                         Phil Spector  2013         2.5
# 11             Don't Stop Believing: Everyman's Journey  2013         3.0
# 12                                       Future Weather  2012         3.5
# 13                                     Bless Me, Ultima  2012         4.0
# 14        A Glimpse Inside the Mind of Charles Swan III  2013         1.0
# 15                                         Side Effects  2013         3.5
# 16                                                56 Up  2013         4.0
# 17                                        Stand Up Guys  2013         3.5
# 18                                              Quartet  2012         2.5
# 19                                 The Loneliest Planet  2013         2.0
# 20                                      West of Memphis  2012         4.0
# 21                                                  LUV  2013         3.0
# 22                           The Trouble with the Truth  2012         3.5
# 23                                    Somewhere Between  2013         3.0
# 24                                                Amour  2013         4.0
# 25                                       Gangster Squad  2012         2.0
# 26                                               Sister  2012         3.5
# 27                                     Zero Dark Thirty  2013         3.0
# 28                                       The Impossible  2012         4.0
# 29                                       The Matchmaker  2012         3.0
# ...                                                 ...   ...         ...
# 7413                                       Triple Cross  1967         2.5
# 7414                  The St. Valentine 's Day Massacre  1967         1.5
# 7415                                            Caprice  1967         2.5
# 7416                                      Chelsea Girls  1967         1.0
# 7417                             Divorce American Style  1967         3.5
# 7418                                       The Way West  1967         2.5
# 7419                                You Only Live Twice  1967         2.5
# 7420                                     The Naked Prey  1967         2.0
# 7421                                   Bullwhip Griffin  1967         3.0
# 7422                                 The Endless Summer  1967         3.0
# 7423                                              Chuka  1967         2.5
# 7424                                 Easy Come, Easy Go  1967         1.0
# 7425                                      The War Wagon  1967         3.0
# 7426                                   Eight on the Lam  1967         2.0
# 7427                                      Hurry Sundown  1967         2.0
# 7428                                      The Honey Pot  1967         3.0
# 7429                             For a Few Dollars More  1967         3.0
# 7430                                      The Happening  1967         2.5
# 7431                                  Echoes of Silence  1967         3.0
# 7432                                         Marat/Sade  1967         4.0
# 7433                                      Casino Royale  1967         2.0
# 7434                                       Africa Addio  1967         0.0
# 7435                                         Good Times  1967         2.5
# 7436                                             Hombre  1967         3.5
# 7437                                  Guns of the Trees  1967         3.0
# 7438                                   The Game Is Over  1967         2.0
# 7439                                 Clouds Over Israel  1967         3.0
# 7440                                      In Like Flint  1967         1.5
# 7441                                              Galia  1967         2.5
# 7442                                    Le Petit Soldat  1960         4.0
#
#                 Genre  Sub-genre   Rating Runtime
# 0                                       R      99
# 1              Comedy                          91
# 2               Drama                   R     105
# 3               Drama    Fantasy    PG-13     104
# 4                                      NR      88
# 5               Drama    Romance        R     112
# 6           Animation      Drama       PG      91
# 7     Science Fiction   Thriller    PG-13     125
# 8               Drama               PG-13      89
# 9           Adventure      Drama        R     137
# 10                                     TV      92
# 11        Documentary                  NR      90
# 12              Drama             Unrated     100
# 13                                  PG-13     106
# 14                                      R      86
# 15              Crime      Drama        R     106
# 16                                     NR     144
# 17             Comedy                   R      95
# 18             Comedy      Drama    PG-13      98
# 19              Drama             Unrated     113
# 20        Documentary                   R     150
# 21              Drama                   R      95
# 22              Drama                   R
# 23        Documentary                  NR
# 24              Drama    Foreign    PG-13     127
# 25              Crime      Drama        R     113
# 26              Drama    Foreign       NR     100
# 27             Action   Thriller        R     157
# 28              Drama               PG-13     114
# 29              Drama                  NR     112
# ...               ...        ...      ...     ...
# 7413           Action  Adventure              140
# 7414            Crime                         100
# 7415           Comedy    Foreign               92
# 7416                                          195
# 7417           Comedy                         109
# 7418           Action  Adventure              122
# 7419           Action    Foreign       PG     117
# 7420           Action      Drama               96
# 7421           Action     Comedy              108
# 7422      Documentary
# 7423           Action      Drama
# 7424        Adventure     Comedy       PG      95
# 7425           Action                          96
# 7426           Comedy                         107
# 7427            Drama                         146
# 7428           Comedy      Drama              125
# 7429           Action    Foreign        R     132
# 7430                                          101
# 7431                                           76
# 7432            Drama    Foreign              116
# 7433           Action  Adventure       NR     131
# 7434      Documentary                   R     122
# 7435                                           91
# 7436           Action      Drama       NR     111
# 7437                                           85
# 7438            Drama    Foreign
# 7439                                   NR      85
# 7440           Action  Adventure              114
# 7441
# 7442            Drama    Foreign       PG      88
#
# [7443 rows x 7 columns]

# %%
df.to_pickle('roger.pickle')
